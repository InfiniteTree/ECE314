# %% [markdown]
# # Lab 11: ODEs, Failure Rates, and Evolutionary Games

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
from scipy.integrate import odeint
print ('Modules Imported!')
# Out:
# Modules Imported!

# %% [markdown]
# In this lab we're to going analyze evolutionary games using drift analysis. In order to do this, we first need to determine how to integrate ordinary differential equations. So, we begin with a brief exposure of how to achieve this in Python. While we're at it, we'll do a short exercise about failure rate functions.  Then we examine some evolutionary games, using both a stochastic model and a deterministic model, which involves the differential equations.

# %% [markdown]
# ## Integration of ODEs

# %% [markdown]
# This section gives an introdution to integrating ordinary differential equations (odes), with an application to the calculation of a CDF from a failure rate function.  If you recall from your math classes we can describe an ODE as the following:
#
# $\dot{y}=f(y),$
#
# where both $y$ and the function $f$ are vector valued, and $\dot{y}$ is shorthand for $\frac{dy}{dt}.$   The variables being vector valued simply implies that we could have a system of dependent one dimensional (1D) ODEs as opposed to just a single one dimensional variable.  Let's look at the following system:
#
# \begin{eqnarray*}
# \binom{\dot{y_0}}{\dot{y_1}} = \binom{2y_1-0.1y_0}{-y_0}
# \end{eqnarray*}
# with the initial condition $y_{init}=\binom{y_1(0)}{y_2(0)}=\binom{1}{1}.$
#
# Our goal in using Python is not to find a closed form solution to the ODE as you would have probably done in your math class, but to numerically integrate it and produce a graphical solution. In order to do this we use the odeint method from scipy.integrate. It takes a function with an initial value and specified times at which the solution is to be output. Internally, the numerical method will often use a much finer grid of time points to solve the ode -- but that is none of your concern.   The times you put in are the times at with the method needs to provide the values of the solution. Look how it is used below:

# %%
# Simple example integrating a 2d ordinary differential equation (ode) dy/dt=f(y,t) 
# Note that the odeint package is imported in the code at the beginning of this file.

# Function to integrate over
def f(y,t):    
    return np.array([2.*y[1]-.1*y[0],-y[0] ])

time=np.linspace(0.0,20.0,10000)   # The times at which the solution is output.
yinit=np.array([1.0,1.0])   # The initial condition
y=odeint(f,yinit,time)      

plt.plot(y[:,0],y[:,1])
plt.title('trajectory of y up to time 20')
plt.ylabel('y_1')
plt.xlabel('y_0')

# %% [markdown]
# Typically in a plot like this you would add an arrow to indicate the direction of time in the graph. However, we know the initial state is $y_{init}=\binom{1}{1}.$ So as time increases, the trajectory moves concentrically inwards in a clockwise fashion. Depending on how much of differential equations you remember, this solution should make sense. The equation happens to have a linear form and can be written as $\dot y = Ay$ where
# $
# A=\left( \begin{array}{cc}  -0.1  &  2  \\  -1  & 0 \end{array} \right).
# $
# The eigenvalues of $A$ are complex with negative real parts, so we would expect a decaying oscillatory behavior. (If you didn't follow that, don't worry about it.)
#
# As a simple application of integrating a 1D (one-dimensional) ode, the following code calculates a CDF $F$ from its failure rate function $h.$ But first, let's look at some theory to remember what a failure rate function is. If we let $T$ be a positive random variable with a pdf $f_T$ then
# the failure rate function is defined by the following:
#
# $$h(t)=\lim_{\epsilon \to 0} \frac{P(t<T \leq t+\epsilon | T>t)}{\epsilon}$$
#
# Equivalently, an object having failure rate function $h$ means that for any $t > 0,$ given
# that the object is still working at time $t$, the probability it will fail in the next
# $\epsilon$ time units is $h(t)\epsilon + o(\epsilon)$.  (As usual, $o(\epsilon)$ represents an error term such that $o(\epsilon)/\epsilon \to 0$ as $\epsilon\to 0.$)  With a little bit more derivation (shown in Section 3.9 of your ECE 313 text), we can see that:
#
# $$h(t) = \frac{f_T(t)}{1-F_T(t)}$$
#
# Of course, the pdf $f_T$ is the derivative of the CDF $F_T$. Here's where your 1D ODE comes into play. Given a failure rate function, we want to be able to calculate the CDF. We can easily turn this into an ODE.
#
# $f_T(t) = (1-F_T(t))h(t)$
#
# Let $F_T(t) = y$ and  $f_T(t) = \frac{dy}{dt} = \dot{y}$, then:
#
# $\dot{y} = (1-y)h(t)$
#
# Now we have our differential equation set up and we can solve it by the same method used in the previous example. For the code below, we define a particular bathtub shaped failure rate function to model the lifetime of a component such as a hard disk drive. There is a high, but decreasing initial rate of failure, followed be a period with a very low rate failure, followed by an increasing rate of failure. You should be able to think of reasons why an object might exhibit this type of failure rate function. Notice that the CDF behaves as we would expect: always between 0 and 1, and reactive to $h(t)$.
#
# If you examine the ECE 313 notes you'll see another way to determine $F_T,$  namely, using
# $F_T(t) = 1- \exp \left( \int_o^t -h(s) ds \right)$.  The point here, though, is to get some practice using
# odeint, instead of using this formula.

# %%
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

plt.plot(time,list(map(h,time)))
plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
plt.text(4,0.5, r'$F(t)$',fontsize=24) 

plt.plot(time,F)
plt.title('failure rate function $h$ and associated CDF, $F$')
plt.axis(ymin=0,ymax=2.0)
plt.ylabel('$h(t), F(t)$',fontsize=20)
plt.xlabel('$t$',fontsize=20)

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 1:</SPAN>** Using the information on failure rate functions and the example above, do the following:
# <ol>
# <li> Write code that, given the failure rate function of a random variable $T$, computes the mean lifetime, $E[T].$  Use this code to determine the mean lifetime for the example given above.  (Hint: An easy way to do this problem is to use the area rule for expectations. Since $T$ is nonnegative, the area rule for expectations gives $E[T]=\int_0^\infty(1-F(t)) dt.$
# The integral $\int_0^\infty (1-F(t)) dt$ is approximately equal to
# $\int_0^{t_{max}} (1-F(t)) dt,$  which, by the definition of Riemann integration, is approximately equal to
# $h \sum_{i=1}^{1000} (1-F(h_i)) $ where $h=t_{max}/1000.$  Basically the code above returns the samples $F(h_i)$ so all you need to do is subtract these values from 1, sum them up and multiply by $h$.)
# <li> What happens to $E[T]$ if the failure rate function is doubled for all time? Print out the new value of $E[T]$.
# </ol>

# %%
# Your code here
print("------------------------------------------Problem 1.1-----------------------------------------------------")
delta_h=t_max/1000
meanValue=0
for [hi] in F:
    meanValue+=delta_h*(1-hi)
print('mean value is:',meanValue)

print("")
print("------------------------------------------Problem 1.2-----------------------------------------------------")
def h_new(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 2*(1-t)
    elif t<3:
        return 0.0
    else:
        return 2*np.sqrt(t-3)
    
def Fdot_new(y,t):    
    return (1-y)*h_new(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F_new=odeint(Fdot_new,Finit,time)

delta_h=t_max/1000
mean_new=0
for [hi] in F_new:
    mean_new+=delta_h*(1-hi)
print('mean value is:',mean_new)
# Out:
# ------------------------------------------Problem 1.1-----------------------------------------------------
# mean value is: 2.656524220052051
#
# ------------------------------------------Problem 1.2-----------------------------------------------------
# mean value is: 1.5504448592454616

# %% [markdown]
# __Answer:__ (Your answer here)
#
# According to the simulation, E[T] decreases as failure rate function is doubled

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 1</SPAN>**

# %% [markdown]
# ## Evolutionary games (replicator dynamics):

# %% [markdown]
# Consider a population of individuals, where each individual is of some type.  Suppose individuals have occasional pairwise encounters.  During an encounter the two individuals involved play a two player symmetric game in which the strategies are the types of the individuals.   As a result of the encounter, each of the two individuals produces a number of offspring of its same type, with the number being determined by a fitess table or, equivalently, a fitness matrix.   For example, consider a population of crickets such that each cricket is either small or large.   If two small crickets meet each other then they each spawn five more small crickets.  If a small cricket encounters a large cricket then the small cricket spawns one more small cricket and the large cricket spawns eight new large crickets.   If two large crickets meet then each of them spawns three new large crickets.  We can summarize these outcomes using the following table:
# $$\begin{array}{c|cc}  & small & large  \\ \hline
#     small & 5 & 1  \\
#     large & 8 & 3
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  5 & 1 \\ 8 & 3  \end{array}\right).$$
# Associating 0 with "small" and 1 with "large,"  we see that if a type i individual encounters a type j individual, then the type i individual spawns F[i,j] new individuals of type i, and the type j individual spawns F[j,i] new individuals of type j. Below is a stochastic simulation for this game where we start with a population of four small crickets and four large crickets. It may be a useful exercise for you to think of how the values for $a$ and $b$ were created.

# %%
# Stochastic simulation of replicator dynamics for cricket game

F=np.array([[5,1],[8,3]])  # fitness matrix

n=np.array([4,4])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 1000 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [0.5 0.5]
# Round 1 two small crickets meet  [14  4] [0.77777778 0.22222222]
# Round 2 a small meets a large    [15 12] [0.55555556 0.44444444]
# Round 3 a small meets a large    [16 20] [0.44444444 0.55555556]
# Round 4 two large crickets meet  [16 26] [0.38095238 0.61904762]
# Round 5 two large crickets meet  [16 32] [0.33333333 0.66666667]
# Round 6 a small meets a large    [17 40] [0.29824561 0.70175439]
# Round 7 a small meets a large    [18 48] [0.27272727 0.72727273]
# Round 8 two small crickets meet  [28 48] [0.36842105 0.63157895]
# Round 9 two large crickets meet  [28 54] [0.34146341 0.65853659]
# Round 10 a small meets a large    [29 62] [0.31868132 0.68131868]
# Round 11 two large crickets meet  [29 68] [0.29896907 0.70103093]
# Round 12 two large crickets meet  [29 74] [0.2815534 0.7184466]
# Round 13 two small crickets meet  [39 74] [0.34513274 0.65486726]
# Round 14 two large crickets meet  [39 80] [0.32773109 0.67226891]
# Round 15 two large crickets meet  [39 86] [0.312 0.688]
# Round 16 a small meets a large    [40 94] [0.29850746 0.70149254]
# Round 17 two large crickets meet  [ 40 100] [0.28571429 0.71428571]
# Round 18 two large crickets meet  [ 40 106] [0.2739726 0.7260274]
# Round 19 a small meets a large    [ 41 114] [0.26451613 0.73548387]
# Round 20 a small meets a large    [ 42 122] [0.25609756 0.74390244]
# Round 21 two large crickets meet  [ 42 128] [0.24705882 0.75294118]
# Round 22 two large crickets meet  [ 42 134] [0.23863636 0.76136364]
# Round 23 two large crickets meet  [ 42 140] [0.23076923 0.76923077]
# Round 24 a small meets a large    [ 43 148] [0.22513089 0.77486911]
# Round 25 two large crickets meet  [ 43 154] [0.21827411 0.78172589]
# Round 26 two large crickets meet  [ 43 160] [0.21182266 0.78817734]
# Round 27 a small meets a large    [ 44 168] [0.20754717 0.79245283]
# Round 28 a small meets a large    [ 45 176] [0.20361991 0.79638009]
# Round 29 a small meets a large    [ 46 184] [0.2 0.8]
# Round 30 two large crickets meet  [ 46 190] [0.19491525 0.80508475]
# Round 31 a small meets a large    [ 47 198] [0.19183673 0.80816327]
# Round 32 two large crickets meet  [ 47 204] [0.187251 0.812749]
# Round 33 two large crickets meet  [ 47 210] [0.18287938 0.81712062]
# Round 34 a small meets a large    [ 48 218] [0.18045113 0.81954887]
# Round 35 two large crickets meet  [ 48 224] [0.17647059 0.82352941]
# Round 36 a small meets a large    [ 49 232] [0.17437722 0.82562278]
# Round 37 two large crickets meet  [ 49 238] [0.17073171 0.82926829]
# Round 38 two large crickets meet  [ 49 244] [0.16723549 0.83276451]
# Round 39 a small meets a large    [ 50 252] [0.16556291 0.83443709]
# Round 40 two large crickets meet  [ 50 258] [0.16233766 0.83766234]
# Round 41 two large crickets meet  [ 50 264] [0.15923567 0.84076433]
# Round 42 two large crickets meet  [ 50 270] [0.15625 0.84375]
# Round 43 two large crickets meet  [ 50 276] [0.15337423 0.84662577]
# Round 44 two large crickets meet  [ 50 282] [0.15060241 0.84939759]
# Round 45 a small meets a large    [ 51 290] [0.14956012 0.85043988]
# Round 46 a small meets a large    [ 52 298] [0.14857143 0.85142857]
# Round 47 a small meets a large    [ 53 306] [0.14763231 0.85236769]
# Round 48 two large crickets meet  [ 53 312] [0.14520548 0.85479452]
# Round 49 a small meets a large    [ 54 320] [0.14438503 0.85561497]
# Round 50 two large crickets meet  [ 54 326] [0.14210526 0.85789474]
# Round 51 two large crickets meet  [ 54 332] [0.13989637 0.86010363]
# Round 52 two large crickets meet  [ 54 338] [0.1377551 0.8622449]
# Round 53 two small crickets meet  [ 64 338] [0.15920398 0.84079602]
# Round 54 a small meets a large    [ 65 346] [0.15815085 0.84184915]
# Round 55 two large crickets meet  [ 65 352] [0.1558753 0.8441247]
# Round 56 two large crickets meet  [ 65 358] [0.1536643 0.8463357]
# Round 57 a small meets a large    [ 66 366] [0.15277778 0.84722222]
# Round 58 two large crickets meet  [ 66 372] [0.15068493 0.84931507]
# Round 59 two large crickets meet  [ 66 378] [0.14864865 0.85135135]
# Round 60 two large crickets meet  [ 66 384] [0.14666667 0.85333333]
# Round 61 two large crickets meet  [ 66 390] [0.14473684 0.85526316]
# Round 62 a small meets a large    [ 67 398] [0.14408602 0.85591398]
# Round 63 two large crickets meet  [ 67 404] [0.14225053 0.85774947]
# Round 64 two large crickets meet  [ 67 410] [0.14046122 0.85953878]
# Round 65 a small meets a large    [ 68 418] [0.1399177 0.8600823]
# Round 66 two small crickets meet  [ 78 418] [0.15725806 0.84274194]
# Round 67 a small meets a large    [ 79 426] [0.15643564 0.84356436]
# Round 68 two large crickets meet  [ 79 432] [0.15459883 0.84540117]
# Round 69 two large crickets meet  [ 79 438] [0.15280464 0.84719536]
# Round 70 a small meets a large    [ 80 446] [0.15209125 0.84790875]
# Round 71 two large crickets meet  [ 80 452] [0.15037594 0.84962406]
# Round 72 two large crickets meet  [ 80 458] [0.14869888 0.85130112]
# Round 73 two large crickets meet  [ 80 464] [0.14705882 0.85294118]
# Round 74 two large crickets meet  [ 80 470] [0.14545455 0.85454545]
# Round 75 a small meets a large    [ 81 478] [0.14490161 0.85509839]
# Round 76 a small meets a large    [ 82 486] [0.1443662 0.8556338]
# Round 77 a small meets a large    [ 83 494] [0.14384749 0.85615251]
# Round 78 two large crickets meet  [ 83 500] [0.14236707 0.85763293]
# Round 79 a small meets a large    [ 84 508] [0.14189189 0.85810811]
# Round 80 two large crickets meet  [ 84 514] [0.14046823 0.85953177]
# Round 81 two large crickets meet  [ 84 520] [0.13907285 0.86092715]
# Round 82 two large crickets meet  [ 84 526] [0.13770492 0.86229508]
# Round 83 a small meets a large    [ 85 534] [0.13731826 0.86268174]
# Round 84 two large crickets meet  [ 85 540] [0.136 0.864]
# Round 85 two large crickets meet  [ 85 546] [0.13470681 0.86529319]
# Round 86 two large crickets meet  [ 85 552] [0.13343799 0.86656201]
# Round 87 a small meets a large    [ 86 560] [0.13312693 0.86687307]
# Round 88 a small meets a large    [ 87 568] [0.13282443 0.86717557]
# Round 89 two large crickets meet  [ 87 574] [0.13161876 0.86838124]
# Round 90 two large crickets meet  [ 87 580] [0.13043478 0.86956522]
# Round 91 a small meets a large    [ 88 588] [0.13017751 0.86982249]
# Round 92 two large crickets meet  [ 88 594] [0.12903226 0.87096774]
# Round 93 two large crickets meet  [ 88 600] [0.12790698 0.87209302]
# Round 94 two large crickets meet  [ 88 606] [0.12680115 0.87319885]
# Round 95 a small meets a large    [ 89 614] [0.12660028 0.87339972]
# Round 96 a small meets a large    [ 90 622] [0.12640449 0.87359551]
# Round 97 two large crickets meet  [ 90 628] [0.12534819 0.87465181]
# Round 98 two large crickets meet  [ 90 634] [0.12430939 0.87569061]
# Round 99 a small meets a large    [ 91 642] [0.12414734 0.87585266]
# Round 100 two large crickets meet  [ 91 648] [0.12313938 0.87686062]
# Round 101 two large crickets meet  [ 91 654] [0.12214765 0.87785235]
# Round 102 two large crickets meet  [ 91 660] [0.12117177 0.87882823]
# Round 103 two large crickets meet  [ 91 666] [0.12021136 0.87978864]
# Round 104 a small meets a large    [ 92 674] [0.12010444 0.87989556]
# Round 105 a small meets a large    [ 93 682] [0.12 0.88]
# Round 106 two large crickets meet  [ 93 688] [0.1190781 0.8809219]
# Round 107 a small meets a large    [ 94 696] [0.11898734 0.88101266]
# Round 108 two large crickets meet  [ 94 702] [0.11809045 0.88190955]
# Round 109 two large crickets meet  [ 94 708] [0.11720698 0.88279302]
# Round 110 two large crickets meet  [ 94 714] [0.11633663 0.88366337]
# Round 111 two large crickets meet  [ 94 720] [0.11547912 0.88452088]
# Round 112 a small meets a large    [ 95 728] [0.11543135 0.88456865]
# Round 113 two large crickets meet  [ 95 734] [0.1145959 0.8854041]
# Round 114 two large crickets meet  [ 95 740] [0.11377246 0.88622754]
# Round 115 two large crickets meet  [ 95 746] [0.11296076 0.88703924]
# Round 116 two large crickets meet  [ 95 752] [0.11216057 0.88783943]
# Round 117 two large crickets meet  [ 95 758] [0.11137163 0.88862837]
# Round 118 two large crickets meet  [ 95 764] [0.11059371 0.88940629]
# Round 119 two large crickets meet  [ 95 770] [0.10982659 0.89017341]
# Round 120 two large crickets meet  [ 95 776] [0.10907003 0.89092997]
# Round 121 two large crickets meet  [ 95 782] [0.10832383 0.89167617]
# Round 122 two large crickets meet  [ 95 788] [0.10758777 0.89241223]
# Round 123 two large crickets meet  [ 95 794] [0.10686164 0.89313836]
# Round 124 two large crickets meet  [ 95 800] [0.10614525 0.89385475]
# Round 125 two large crickets meet  [ 95 806] [0.1054384 0.8945616]
# Round 126 two large crickets meet  [ 95 812] [0.1047409 0.8952591]
# Round 127 two large crickets meet  [ 95 818] [0.10405257 0.89594743]
# Round 128 two large crickets meet  [ 95 824] [0.10337323 0.89662677]
# Round 129 two large crickets meet  [ 95 830] [0.1027027 0.8972973]
# Round 130 two large crickets meet  [ 95 836] [0.10204082 0.89795918]
# Round 131 a small meets a large    [ 96 844] [0.10212766 0.89787234]
# Round 132 two large crickets meet  [ 96 850] [0.10147992 0.89852008]
# Round 133 two large crickets meet  [ 96 856] [0.10084034 0.89915966]
# Round 134 two large crickets meet  [ 96 862] [0.10020877 0.89979123]
# Round 135 two large crickets meet  [ 96 868] [0.09958506 0.90041494]
# Round 136 two large crickets meet  [ 96 874] [0.09896907 0.90103093]
# Round 137 two large crickets meet  [ 96 880] [0.09836066 0.90163934]
# Round 138 a small meets a large    [ 97 888] [0.09847716 0.90152284]
# Round 139 two large crickets meet  [ 97 894] [0.09788093 0.90211907]
# Round 140 two large crickets meet  [ 97 900] [0.09729188 0.90270812]
# Round 141 two large crickets meet  [ 97 906] [0.09670987 0.90329013]
# Round 142 two large crickets meet  [ 97 912] [0.09613479 0.90386521]
# Round 143 two large crickets meet  [ 97 918] [0.0955665 0.9044335]
# Round 144 two large crickets meet  [ 97 924] [0.0950049 0.9049951]
# Round 145 two large crickets meet  [ 97 930] [0.09444985 0.90555015]
# Round 146 a small meets a large    [ 98 938] [0.09459459 0.90540541]
# Round 147 two large crickets meet  [ 98 944] [0.0940499 0.9059501]
# Round 148 two large crickets meet  [ 98 950] [0.09351145 0.90648855]
# Round 149 two large crickets meet  [ 98 956] [0.09297913 0.90702087]
# Round 150 two large crickets meet  [ 98 962] [0.09245283 0.90754717]
# Round 151 two large crickets meet  [ 98 968] [0.09193246 0.90806754]
# Round 152 two large crickets meet  [ 98 974] [0.09141791 0.90858209]
# Round 153 two large crickets meet  [ 98 980] [0.09090909 0.90909091]
# Round 154 a small meets a large    [ 99 988] [0.09107636 0.90892364]
# Round 155 two large crickets meet  [ 99 994] [0.0905764 0.9094236]
# Round 156 two large crickets meet  [  99 1000] [0.09008189 0.90991811]
# Round 157 two large crickets meet  [  99 1006] [0.08959276 0.91040724]
# Round 158 two large crickets meet  [  99 1012] [0.08910891 0.91089109]
# Round 159 two large crickets meet  [  99 1018] [0.08863026 0.91136974]
# Round 160 a small meets a large    [ 100 1026] [0.08880995 0.91119005]
# Round 161 two large crickets meet  [ 100 1032] [0.08833922 0.91166078]
# Round 162 two large crickets meet  [ 100 1038] [0.08787346 0.91212654]
# Round 163 two large crickets meet  [ 100 1044] [0.08741259 0.91258741]
# Round 164 two large crickets meet  [ 100 1050] [0.08695652 0.91304348]
# Round 165 two large crickets meet  [ 100 1056] [0.08650519 0.91349481]
# Round 166 two large crickets meet  [ 100 1062] [0.08605852 0.91394148]
# Round 167 two large crickets meet  [ 100 1068] [0.08561644 0.91438356]
# Round 168 a small meets a large    [ 101 1076] [0.08581138 0.91418862]
# Round 169 two large crickets meet  [ 101 1082] [0.08537616 0.91462384]
# Round 170 two large crickets meet  [ 101 1088] [0.08494533 0.91505467]
# Round 171 two large crickets meet  [ 101 1094] [0.08451883 0.91548117]
# Round 172 two large crickets meet  [ 101 1100] [0.08409659 0.91590341]
# Round 173 two large crickets meet  [ 101 1106] [0.08367854 0.91632146]
# Round 174 two large crickets meet  [ 101 1112] [0.08326463 0.91673537]
# Round 175 a small meets a large    [ 102 1120] [0.08346972 0.91653028]
# Round 176 two large crickets meet  [ 102 1126] [0.08306189 0.91693811]
# Round 177 two large crickets meet  [ 102 1132] [0.08265802 0.91734198]
# Round 178 two large crickets meet  [ 102 1138] [0.08225806 0.91774194]
# Round 179 two large crickets meet  [ 102 1144] [0.08186196 0.91813804]
# Round 180 two large crickets meet  [ 102 1150] [0.08146965 0.91853035]
# Round 181 two large crickets meet  [ 102 1156] [0.08108108 0.91891892]
# Round 182 two large crickets meet  [ 102 1162] [0.0806962 0.9193038]
# Round 183 two large crickets meet  [ 102 1168] [0.08031496 0.91968504]
# Round 184 two large crickets meet  [ 102 1174] [0.0799373 0.9200627]
# Round 185 two large crickets meet  [ 102 1180] [0.07956318 0.92043682]
# Round 186 two large crickets meet  [ 102 1186] [0.07919255 0.92080745]
# Round 187 two large crickets meet  [ 102 1192] [0.07882535 0.92117465]
# Round 188 two large crickets meet  [ 102 1198] [0.07846154 0.92153846]
# Round 189 two large crickets meet  [ 102 1204] [0.07810107 0.92189893]
# Round 190 two large crickets meet  [ 102 1210] [0.0777439 0.9222561]
# Round 191 two large crickets meet  [ 102 1216] [0.07738998 0.92261002]
# Round 192 a small meets a large    [ 103 1224] [0.07761869 0.92238131]
# Round 193 two large crickets meet  [ 103 1230] [0.07726932 0.92273068]
# Round 194 two large crickets meet  [ 103 1236] [0.07692308 0.92307692]
# Round 195 two large crickets meet  [ 103 1242] [0.07657993 0.92342007]
# Round 196 two large crickets meet  [ 103 1248] [0.07623982 0.92376018]
# Round 197 two large crickets meet  [ 103 1254] [0.07590273 0.92409727]
# Round 198 two large crickets meet  [ 103 1260] [0.0755686 0.9244314]
# Round 199 two large crickets meet  [ 103 1266] [0.0752374 0.9247626]
# Round 200 two large crickets meet  [ 103 1272] [0.07490909 0.92509091]
# Round 201 two large crickets meet  [ 103 1278] [0.07458364 0.92541636]
# Round 202 two large crickets meet  [ 103 1284] [0.07426099 0.92573901]
# Round 203 two large crickets meet  [ 103 1290] [0.07394113 0.92605887]
# Round 204 a small meets a large    [ 104 1298] [0.07417974 0.92582026]
# Round 205 two large crickets meet  [ 104 1304] [0.07386364 0.92613636]
# Round 206 two large crickets meet  [ 104 1310] [0.07355021 0.92644979]
# Round 207 two large crickets meet  [ 104 1316] [0.07323944 0.92676056]
# Round 208 two large crickets meet  [ 104 1322] [0.07293128 0.92706872]
# Round 209 two large crickets meet  [ 104 1328] [0.0726257 0.9273743]
# Round 210 two large crickets meet  [ 104 1334] [0.07232267 0.92767733]
# Round 211 a small meets a large    [ 105 1342] [0.07256393 0.92743607]
# Round 212 two large crickets meet  [ 105 1348] [0.07226428 0.92773572]
# Round 213 two large crickets meet  [ 105 1354] [0.0719671 0.9280329]
# Round 214 two large crickets meet  [ 105 1360] [0.07167235 0.92832765]
# Round 215 two large crickets meet  [ 105 1366] [0.07138001 0.92861999]
# Round 216 two large crickets meet  [ 105 1372] [0.07109005 0.92890995]
# Round 217 a small meets a large    [ 106 1380] [0.07133244 0.92866756]
# Round 218 two large crickets meet  [ 106 1386] [0.07104558 0.92895442]
# Round 219 two large crickets meet  [ 106 1392] [0.07076101 0.92923899]
# Round 220 two large crickets meet  [ 106 1398] [0.07047872 0.92952128]
# Round 221 two large crickets meet  [ 106 1404] [0.07019868 0.92980132]
# Round 222 two large crickets meet  [ 106 1410] [0.06992084 0.93007916]
# Round 223 two large crickets meet  [ 106 1416] [0.0696452 0.9303548]
# Round 224 two large crickets meet  [ 106 1422] [0.06937173 0.93062827]
# Round 225 two large crickets meet  [ 106 1428] [0.06910039 0.93089961]
# Round 226 two large crickets meet  [ 106 1434] [0.06883117 0.93116883]
# Round 227 two large crickets meet  [ 106 1440] [0.06856404 0.93143596]
# Round 228 two large crickets meet  [ 106 1446] [0.06829897 0.93170103]
# Round 229 two large crickets meet  [ 106 1452] [0.06803594 0.93196406]
# Round 230 two large crickets meet  [ 106 1458] [0.06777494 0.93222506]
# Round 231 two large crickets meet  [ 106 1464] [0.06751592 0.93248408]
# Round 232 two large crickets meet  [ 106 1470] [0.06725888 0.93274112]
# Round 233 two large crickets meet  [ 106 1476] [0.06700379 0.93299621]
# Round 234 two large crickets meet  [ 106 1482] [0.06675063 0.93324937]
# Round 235 two large crickets meet  [ 106 1488] [0.06649937 0.93350063]
# Round 236 two large crickets meet  [ 106 1494] [0.06625 0.93375]
# Round 237 two large crickets meet  [ 106 1500] [0.06600249 0.93399751]
# Round 238 two large crickets meet  [ 106 1506] [0.06575682 0.93424318]
# Round 239 a small meets a large    [ 107 1514] [0.06600864 0.93399136]
# Round 240 two large crickets meet  [ 107 1520] [0.06576521 0.93423479]
# Round 241 two large crickets meet  [ 107 1526] [0.06552358 0.93447642]
# Round 242 two large crickets meet  [ 107 1532] [0.06528371 0.93471629]
# Round 243 two large crickets meet  [ 107 1538] [0.06504559 0.93495441]
# Round 244 two large crickets meet  [ 107 1544] [0.06480921 0.93519079]
# Round 245 a small meets a large    [ 108 1552] [0.06506024 0.93493976]
# Round 246 two large crickets meet  [ 108 1558] [0.06482593 0.93517407]
# Round 247 two large crickets meet  [ 108 1564] [0.0645933 0.9354067]
# Round 248 two large crickets meet  [ 108 1570] [0.06436234 0.93563766]
# Round 249 two large crickets meet  [ 108 1576] [0.06413302 0.93586698]
# Round 250 two large crickets meet  [ 108 1582] [0.06390533 0.93609467]
# Round 251 a small meets a large    [ 109 1590] [0.06415539 0.93584461]
# Round 252 two large crickets meet  [ 109 1596] [0.06392962 0.93607038]
# Round 253 two large crickets meet  [ 109 1602] [0.06370544 0.93629456]
# Round 254 two large crickets meet  [ 109 1608] [0.06348282 0.93651718]
# Round 255 two large crickets meet  [ 109 1614] [0.06326175 0.93673825]
# Round 256 two large crickets meet  [ 109 1620] [0.06304222 0.93695778]
# Round 257 two large crickets meet  [ 109 1626] [0.06282421 0.93717579]
# Round 258 a small meets a large    [ 110 1634] [0.06307339 0.93692661]
# Round 259 a small meets a large    [ 111 1642] [0.06332002 0.93667998]
# Round 260 two large crickets meet  [ 111 1648] [0.06310404 0.93689596]
# Round 261 two small crickets meet  [ 121 1648] [0.06840023 0.93159977]
# Round 262 two large crickets meet  [ 121 1654] [0.06816901 0.93183099]
# Round 263 two large crickets meet  [ 121 1660] [0.06793936 0.93206064]
# Round 264 two large crickets meet  [ 121 1666] [0.06771125 0.93228875]
# Round 265 two large crickets meet  [ 121 1672] [0.06748466 0.93251534]
# Round 266 two large crickets meet  [ 121 1678] [0.06725959 0.93274041]
# Round 267 two large crickets meet  [ 121 1684] [0.06703601 0.93296399]
# Round 268 two large crickets meet  [ 121 1690] [0.06681391 0.93318609]
# Round 269 two large crickets meet  [ 121 1696] [0.06659329 0.93340671]
# Round 270 two large crickets meet  [ 121 1702] [0.06637411 0.93362589]
# Round 271 two large crickets meet  [ 121 1708] [0.06615637 0.93384363]
# Round 272 two large crickets meet  [ 121 1714] [0.06594005 0.93405995]
# Round 273 two large crickets meet  [ 121 1720] [0.06572515 0.93427485]
# Round 274 two large crickets meet  [ 121 1726] [0.06551164 0.93448836]
# Round 275 two large crickets meet  [ 121 1732] [0.06529951 0.93470049]
# Round 276 two large crickets meet  [ 121 1738] [0.06508876 0.93491124]
# Round 277 two large crickets meet  [ 121 1744] [0.06487936 0.93512064]
# Round 278 two large crickets meet  [ 121 1750] [0.0646713 0.9353287]
# Round 279 two large crickets meet  [ 121 1756] [0.06446457 0.93553543]
# Round 280 two large crickets meet  [ 121 1762] [0.06425916 0.93574084]
# Round 281 two large crickets meet  [ 121 1768] [0.06405506 0.93594494]
# Round 282 two large crickets meet  [ 121 1774] [0.06385224 0.93614776]
# Round 283 two large crickets meet  [ 121 1780] [0.06365071 0.93634929]
# Round 284 two large crickets meet  [ 121 1786] [0.06345045 0.93654955]
# Round 285 two large crickets meet  [ 121 1792] [0.06325144 0.93674856]
# Round 286 a small meets a large    [ 122 1800] [0.06347555 0.93652445]
# Round 287 two large crickets meet  [ 122 1806] [0.06327801 0.93672199]
# Round 288 two large crickets meet  [ 122 1812] [0.0630817 0.9369183]
# Round 289 two large crickets meet  [ 122 1818] [0.0628866 0.9371134]
# Round 290 two large crickets meet  [ 122 1824] [0.0626927 0.9373073]
# Round 291 a small meets a large    [ 123 1832] [0.0629156 0.9370844]
# Round 292 two large crickets meet  [ 123 1838] [0.0627231 0.9372769]
# Round 293 two large crickets meet  [ 123 1844] [0.06253177 0.93746823]
# Round 294 two large crickets meet  [ 123 1850] [0.06234161 0.93765839]
# Round 295 two large crickets meet  [ 123 1856] [0.0621526 0.9378474]
# Round 296 two large crickets meet  [ 123 1862] [0.06196474 0.93803526]
# Round 297 two large crickets meet  [ 123 1868] [0.061778 0.938222]
# Round 298 two large crickets meet  [ 123 1874] [0.06159239 0.93840761]
# Round 299 a small meets a large    [ 124 1882] [0.06181456 0.93818544]
# Round 300 a small meets a large    [ 125 1890] [0.06203474 0.93796526]
# Round 301 two large crickets meet  [ 125 1896] [0.06185057 0.93814943]
# Round 302 two large crickets meet  [ 125 1902] [0.06166749 0.93833251]
# Round 303 two large crickets meet  [ 125 1908] [0.06148549 0.93851451]
# Round 304 two large crickets meet  [ 125 1914] [0.06130456 0.93869544]
# Round 305 two large crickets meet  [ 125 1920] [0.06112469 0.93887531]
# Round 306 two large crickets meet  [ 125 1926] [0.06094588 0.93905412]
# Round 307 two large crickets meet  [ 125 1932] [0.06076811 0.93923189]
# Round 308 two large crickets meet  [ 125 1938] [0.06059137 0.93940863]
# Round 309 two large crickets meet  [ 125 1944] [0.06041566 0.93958434]
# Round 310 two large crickets meet  [ 125 1950] [0.06024096 0.93975904]
# Round 311 two large crickets meet  [ 125 1956] [0.06006728 0.93993272]
# Round 312 two large crickets meet  [ 125 1962] [0.05989459 0.94010541]
# Round 313 a small meets a large    [ 126 1970] [0.0601145 0.9398855]
# Round 314 two large crickets meet  [ 126 1976] [0.05994291 0.94005709]
# Round 315 two large crickets meet  [ 126 1982] [0.0597723 0.9402277]
# Round 316 two large crickets meet  [ 126 1988] [0.05960265 0.94039735]
# Round 317 two large crickets meet  [ 126 1994] [0.05943396 0.94056604]
# Round 318 a small meets a large    [ 127 2002] [0.05965242 0.94034758]
# Round 319 two large crickets meet  [ 127 2008] [0.05948478 0.94051522]
# Round 320 two large crickets meet  [ 127 2014] [0.05931808 0.94068192]
# Round 321 two large crickets meet  [ 127 2020] [0.05915231 0.94084769]
# Round 322 a small meets a large    [ 128 2028] [0.0593692 0.9406308]
# Round 323 two large crickets meet  [ 128 2034] [0.05920444 0.94079556]
# Round 324 a small meets a large    [ 129 2042] [0.05941962 0.94058038]
# Round 325 two large crickets meet  [ 129 2048] [0.05925586 0.94074414]
# Round 326 two large crickets meet  [ 129 2054] [0.05909299 0.94090701]
# Round 327 two large crickets meet  [ 129 2060] [0.05893102 0.94106898]
# Round 328 two large crickets meet  [ 129 2066] [0.05876993 0.94123007]
# Round 329 two large crickets meet  [ 129 2072] [0.05860972 0.94139028]
# Round 330 two large crickets meet  [ 129 2078] [0.05845039 0.94154961]
# Round 331 two large crickets meet  [ 129 2084] [0.05829191 0.94170809]
# Round 332 two large crickets meet  [ 129 2090] [0.05813429 0.94186571]
# Round 333 a small meets a large    [ 130 2098] [0.05834829 0.94165171]
# Round 334 two large crickets meet  [ 130 2104] [0.05819158 0.94180842]
# Round 335 two large crickets meet  [ 130 2110] [0.05803571 0.94196429]
# Round 336 a small meets a large    [ 131 2118] [0.05824811 0.94175189]
# Round 337 two large crickets meet  [ 131 2124] [0.05809313 0.94190687]
# Round 338 two large crickets meet  [ 131 2130] [0.05793897 0.94206103]
# Round 339 a small meets a large    [ 132 2138] [0.05814978 0.94185022]
# Round 340 a small meets a large    [ 133 2146] [0.05835893 0.94164107]
# Round 341 two large crickets meet  [ 133 2152] [0.05820569 0.94179431]
# Round 342 two large crickets meet  [ 133 2158] [0.05805325 0.94194675]
# Round 343 two large crickets meet  [ 133 2164] [0.05790161 0.94209839]
# Round 344 two large crickets meet  [ 133 2170] [0.05775076 0.94224924]
# Round 345 two large crickets meet  [ 133 2176] [0.05760069 0.94239931]
# Round 346 two large crickets meet  [ 133 2182] [0.0574514 0.9425486]
# Round 347 two large crickets meet  [ 133 2188] [0.05730289 0.94269711]
# Round 348 two large crickets meet  [ 133 2194] [0.05715514 0.94284486]
# Round 349 two large crickets meet  [ 133 2200] [0.05700814 0.94299186]
# Round 350 two large crickets meet  [ 133 2206] [0.05686191 0.94313809]
# Round 351 two large crickets meet  [ 133 2212] [0.05671642 0.94328358]
# Round 352 a small meets a large    [ 134 2220] [0.05692438 0.94307562]
# Round 353 two large crickets meet  [ 134 2226] [0.05677966 0.94322034]
# Round 354 two large crickets meet  [ 134 2232] [0.05663567 0.94336433]
# Round 355 two large crickets meet  [ 134 2238] [0.05649241 0.94350759]
# Round 356 two large crickets meet  [ 134 2244] [0.05634987 0.94365013]
# Round 357 two large crickets meet  [ 134 2250] [0.05620805 0.94379195]
# Round 358 two large crickets meet  [ 134 2256] [0.05606695 0.94393305]
# Round 359 two large crickets meet  [ 134 2262] [0.05592654 0.94407346]
# Round 360 two large crickets meet  [ 134 2268] [0.05578684 0.94421316]
# Round 361 two large crickets meet  [ 134 2274] [0.05564784 0.94435216]
# Round 362 two large crickets meet  [ 134 2280] [0.05550953 0.94449047]
# Round 363 two large crickets meet  [ 134 2286] [0.0553719 0.9446281]
# Round 364 two large crickets meet  [ 134 2292] [0.05523495 0.94476505]
# Round 365 two large crickets meet  [ 134 2298] [0.05509868 0.94490132]
# Round 366 two large crickets meet  [ 134 2304] [0.05496308 0.94503692]
# Round 367 two large crickets meet  [ 134 2310] [0.05482815 0.94517185]
# Round 368 two large crickets meet  [ 134 2316] [0.05469388 0.94530612]
# Round 369 two large crickets meet  [ 134 2322] [0.05456026 0.94543974]
# Round 370 a small meets a large    [ 135 2330] [0.05476673 0.94523327]
# Round 371 two large crickets meet  [ 135 2336] [0.05463375 0.94536625]
# Round 372 two large crickets meet  [ 135 2342] [0.05450141 0.94549859]
# Round 373 two large crickets meet  [ 135 2348] [0.05436971 0.94563029]
# Round 374 two large crickets meet  [ 135 2354] [0.05423865 0.94576135]
# Round 375 two large crickets meet  [ 135 2360] [0.05410822 0.94589178]
# Round 376 two large crickets meet  [ 135 2366] [0.05397841 0.94602159]
# Round 377 two large crickets meet  [ 135 2372] [0.05384922 0.94615078]
# Round 378 two large crickets meet  [ 135 2378] [0.05372065 0.94627935]
# Round 379 two large crickets meet  [ 135 2384] [0.0535927 0.9464073]
# Round 380 two large crickets meet  [ 135 2390] [0.05346535 0.94653465]
# Round 381 two large crickets meet  [ 135 2396] [0.0533386 0.9466614]
# Round 382 two large crickets meet  [ 135 2402] [0.05321246 0.94678754]
# Round 383 two large crickets meet  [ 135 2408] [0.05308691 0.94691309]
# Round 384 two large crickets meet  [ 135 2414] [0.05296195 0.94703805]
# Round 385 two large crickets meet  [ 135 2420] [0.05283757 0.94716243]
# Round 386 two large crickets meet  [ 135 2426] [0.05271378 0.94728622]
# Round 387 two large crickets meet  [ 135 2432] [0.05259057 0.94740943]
# Round 388 two large crickets meet  [ 135 2438] [0.05246794 0.94753206]
# Round 389 two large crickets meet  [ 135 2444] [0.05234587 0.94765413]
# Round 390 two large crickets meet  [ 135 2450] [0.05222437 0.94777563]
# Round 391 two large crickets meet  [ 135 2456] [0.05210343 0.94789657]
# Round 392 two large crickets meet  [ 135 2462] [0.05198306 0.94801694]
# Round 393 two large crickets meet  [ 135 2468] [0.05186323 0.94813677]
# Round 394 two large crickets meet  [ 135 2474] [0.05174396 0.94825604]
# Round 395 two large crickets meet  [ 135 2480] [0.05162524 0.94837476]
# Round 396 two large crickets meet  [ 135 2486] [0.05150706 0.94849294]
# Round 397 two large crickets meet  [ 135 2492] [0.05138942 0.94861058]
# Round 398 a small meets a large    [ 136 2500] [0.05159332 0.94840668]
# Round 399 a small meets a large    [ 137 2508] [0.05179584 0.94820416]
# Round 400 a small meets a large    [ 138 2516] [0.05199699 0.94800301]
# Round 401 two large crickets meet  [ 138 2522] [0.0518797 0.9481203]
# Round 402 two large crickets meet  [ 138 2528] [0.05176294 0.94823706]
# Round 403 two large crickets meet  [ 138 2534] [0.05164671 0.94835329]
# Round 404 two large crickets meet  [ 138 2540] [0.05153099 0.94846901]
# Round 405 a small meets a large    [ 139 2548] [0.05173055 0.94826945]
# Round 406 two large crickets meet  [ 139 2554] [0.0516153 0.9483847]
# Round 407 two large crickets meet  [ 139 2560] [0.05150056 0.94849944]
# Round 408 two large crickets meet  [ 139 2566] [0.05138632 0.94861368]
# Round 409 two large crickets meet  [ 139 2572] [0.05127259 0.94872741]
# Round 410 two large crickets meet  [ 139 2578] [0.05115937 0.94884063]
# Round 411 two large crickets meet  [ 139 2584] [0.05104664 0.94895336]
# Round 412 two large crickets meet  [ 139 2590] [0.05093441 0.94906559]
# Round 413 a small meets a large    [ 140 2598] [0.05113221 0.94886779]
# Round 414 two large crickets meet  [ 140 2604] [0.05102041 0.94897959]
# Round 415 two large crickets meet  [ 140 2610] [0.05090909 0.94909091]
# Round 416 two large crickets meet  [ 140 2616] [0.05079826 0.94920174]
# Round 417 two large crickets meet  [ 140 2622] [0.05068791 0.94931209]
# Round 418 two large crickets meet  [ 140 2628] [0.05057803 0.94942197]
# Round 419 a small meets a large    [ 141 2636] [0.05077422 0.94922578]
# Round 420 two large crickets meet  [ 141 2642] [0.05066475 0.94933525]
# Round 421 two large crickets meet  [ 141 2648] [0.05055575 0.94944425]
# Round 422 two large crickets meet  [ 141 2654] [0.05044723 0.94955277]
# Round 423 two large crickets meet  [ 141 2660] [0.05033916 0.94966084]
# Round 424 two large crickets meet  [ 141 2666] [0.05023156 0.94976844]
# Round 425 two large crickets meet  [ 141 2672] [0.05012442 0.94987558]
# Round 426 two large crickets meet  [ 141 2678] [0.05001774 0.94998226]
# Round 427 two large crickets meet  [ 141 2684] [0.0499115 0.9500885]
# Round 428 two large crickets meet  [ 141 2690] [0.04980572 0.95019428]
# Round 429 two large crickets meet  [ 141 2696] [0.04970039 0.95029961]
# Round 430 a small meets a large    [ 142 2704] [0.04989459 0.95010541]
# Round 431 a small meets a large    [ 143 2712] [0.05008757 0.94991243]
# Round 432 two large crickets meet  [ 143 2718] [0.04998252 0.95001748]
# Round 433 two large crickets meet  [ 143 2724] [0.04987792 0.95012208]
# Round 434 two large crickets meet  [ 143 2730] [0.04977376 0.95022624]
# Round 435 two large crickets meet  [ 143 2736] [0.04967002 0.95032998]
# Round 436 two large crickets meet  [ 143 2742] [0.04956672 0.95043328]
# Round 437 two large crickets meet  [ 143 2748] [0.04946385 0.95053615]
# Round 438 two large crickets meet  [ 143 2754] [0.04936141 0.95063859]
# Round 439 two large crickets meet  [ 143 2760] [0.04925939 0.95074061]
# Round 440 two large crickets meet  [ 143 2766] [0.04915779 0.95084221]
# Round 441 two large crickets meet  [ 143 2772] [0.0490566 0.9509434]
# Round 442 two large crickets meet  [ 143 2778] [0.04895584 0.95104416]
# Round 443 two large crickets meet  [ 143 2784] [0.04885548 0.95114452]
# Round 444 two large crickets meet  [ 143 2790] [0.04875554 0.95124446]
# Round 445 two large crickets meet  [ 143 2796] [0.04865601 0.95134399]
# Round 446 two large crickets meet  [ 143 2802] [0.04855688 0.95144312]
# Round 447 two large crickets meet  [ 143 2808] [0.04845815 0.95154185]
# Round 448 two large crickets meet  [ 143 2814] [0.04835982 0.95164018]
# Round 449 two large crickets meet  [ 143 2820] [0.0482619 0.9517381]
# Round 450 two large crickets meet  [ 143 2826] [0.04816437 0.95183563]
# Round 451 two large crickets meet  [ 143 2832] [0.04806723 0.95193277]
# Round 452 two large crickets meet  [ 143 2838] [0.04797048 0.95202952]
# Round 453 two large crickets meet  [ 143 2844] [0.04787412 0.95212588]
# Round 454 two large crickets meet  [ 143 2850] [0.04777815 0.95222185]
# Round 455 two large crickets meet  [ 143 2856] [0.04768256 0.95231744]
# Round 456 two large crickets meet  [ 143 2862] [0.04758735 0.95241265]
# Round 457 two large crickets meet  [ 143 2868] [0.04749253 0.95250747]
# Round 458 two small crickets meet  [ 153 2868] [0.05064548 0.94935452]
# Round 459 two large crickets meet  [ 153 2874] [0.05054509 0.94945491]
# Round 460 two large crickets meet  [ 153 2880] [0.0504451 0.9495549]
# Round 461 two large crickets meet  [ 153 2886] [0.05034551 0.94965449]
# Round 462 two large crickets meet  [ 153 2892] [0.05024631 0.94975369]
# Round 463 two large crickets meet  [ 153 2898] [0.05014749 0.94985251]
# Round 464 two large crickets meet  [ 153 2904] [0.05004907 0.94995093]
# Round 465 two large crickets meet  [ 153 2910] [0.04995103 0.95004897]
# Round 466 two large crickets meet  [ 153 2916] [0.04985337 0.95014663]
# Round 467 two large crickets meet  [ 153 2922] [0.0497561 0.9502439]
# Round 468 two large crickets meet  [ 153 2928] [0.0496592 0.9503408]
# Round 469 two large crickets meet  [ 153 2934] [0.04956268 0.95043732]
# Round 470 two large crickets meet  [ 153 2940] [0.04946654 0.95053346]
# Round 471 two large crickets meet  [ 153 2946] [0.04937076 0.95062924]
# Round 472 two large crickets meet  [ 153 2952] [0.04927536 0.95072464]
# Round 473 two large crickets meet  [ 153 2958] [0.04918033 0.95081967]
# Round 474 two large crickets meet  [ 153 2964] [0.04908566 0.95091434]
# Round 475 two large crickets meet  [ 153 2970] [0.04899135 0.95100865]
# Round 476 two large crickets meet  [ 153 2976] [0.04889741 0.95110259]
# Round 477 two large crickets meet  [ 153 2982] [0.04880383 0.95119617]
# Round 478 two large crickets meet  [ 153 2988] [0.0487106 0.9512894]
# Round 479 two large crickets meet  [ 153 2994] [0.04861773 0.95138227]
# Round 480 two large crickets meet  [ 153 3000] [0.04852521 0.95147479]
# Round 481 two large crickets meet  [ 153 3006] [0.04843305 0.95156695]
# Round 482 two large crickets meet  [ 153 3012] [0.04834123 0.95165877]
# Round 483 two large crickets meet  [ 153 3018] [0.04824976 0.95175024]
# Round 484 two large crickets meet  [ 153 3024] [0.04815864 0.95184136]
# Round 485 two large crickets meet  [ 153 3030] [0.04806786 0.95193214]
# Round 486 two large crickets meet  [ 153 3036] [0.04797742 0.95202258]
# Round 487 two large crickets meet  [ 153 3042] [0.04788732 0.95211268]
# Round 488 two large crickets meet  [ 153 3048] [0.04779756 0.95220244]
# Round 489 two large crickets meet  [ 153 3054] [0.04770814 0.95229186]
# Round 490 two large crickets meet  [ 153 3060] [0.04761905 0.95238095]
# Round 491 two large crickets meet  [ 153 3066] [0.04753029 0.95246971]
# Round 492 two large crickets meet  [ 153 3072] [0.04744186 0.95255814]
# Round 493 two large crickets meet  [ 153 3078] [0.04735376 0.95264624]
# Round 494 two large crickets meet  [ 153 3084] [0.04726599 0.95273401]
# Round 495 two large crickets meet  [ 153 3090] [0.04717854 0.95282146]
# Round 496 two large crickets meet  [ 153 3096] [0.04709141 0.95290859]
# Round 497 two large crickets meet  [ 153 3102] [0.04700461 0.95299539]
# Round 498 two large crickets meet  [ 153 3108] [0.04691812 0.95308188]
# Round 499 two large crickets meet  [ 153 3114] [0.04683196 0.95316804]
# Round 500 two large crickets meet  [ 153 3120] [0.0467461 0.9532539]
# Round 501 a small meets a large    [ 154 3128] [0.04692261 0.95307739]
# Round 502 two large crickets meet  [ 154 3134] [0.04683698 0.95316302]
# Round 503 two large crickets meet  [ 154 3140] [0.04675167 0.95324833]
# Round 504 two large crickets meet  [ 154 3146] [0.04666667 0.95333333]
# Round 505 two large crickets meet  [ 154 3152] [0.04658197 0.95341803]
# Round 506 two large crickets meet  [ 154 3158] [0.04649758 0.95350242]
# Round 507 two large crickets meet  [ 154 3164] [0.0464135 0.9535865]
# Round 508 two large crickets meet  [ 154 3170] [0.04632972 0.95367028]
# Round 509 two large crickets meet  [ 154 3176] [0.04624625 0.95375375]
# Round 510 two large crickets meet  [ 154 3182] [0.04616307 0.95383693]
# Round 511 two large crickets meet  [ 154 3188] [0.04608019 0.95391981]
# Round 512 two large crickets meet  [ 154 3194] [0.04599761 0.95400239]
# Round 513 a small meets a large    [ 155 3202] [0.04617218 0.95382782]
# Round 514 two large crickets meet  [ 155 3208] [0.0460898 0.9539102]
# Round 515 two large crickets meet  [ 155 3214] [0.04600772 0.95399228]
# Round 516 a small meets a large    [ 156 3222] [0.04618117 0.95381883]
# Round 517 a small meets a large    [ 157 3230] [0.04635371 0.95364629]
# Round 518 two large crickets meet  [ 157 3236] [0.04627174 0.95372826]
# Round 519 two large crickets meet  [ 157 3242] [0.04619006 0.95380994]
# Round 520 two large crickets meet  [ 157 3248] [0.04610866 0.95389134]
# Round 521 a small meets a large    [ 158 3256] [0.04628002 0.95371998]
# Round 522 two large crickets meet  [ 158 3262] [0.04619883 0.95380117]
# Round 523 two large crickets meet  [ 158 3268] [0.04611792 0.95388208]
# Round 524 two large crickets meet  [ 158 3274] [0.0460373 0.9539627]
# Round 525 two large crickets meet  [ 158 3280] [0.04595695 0.95404305]
# Round 526 two large crickets meet  [ 158 3286] [0.04587689 0.95412311]
# Round 527 two large crickets meet  [ 158 3292] [0.0457971 0.9542029]
# Round 528 a small meets a large    [ 159 3300] [0.04596704 0.95403296]
# Round 529 two large crickets meet  [ 159 3306] [0.04588745 0.95411255]
# Round 530 two large crickets meet  [ 159 3312] [0.04580812 0.95419188]
# Round 531 two large crickets meet  [ 159 3318] [0.04572908 0.95427092]
# Round 532 two large crickets meet  [ 159 3324] [0.0456503 0.9543497]
# Round 533 two large crickets meet  [ 159 3330] [0.0455718 0.9544282]
# Round 534 two large crickets meet  [ 159 3336] [0.04549356 0.95450644]
# Round 535 two large crickets meet  [ 159 3342] [0.0454156 0.9545844]
# Round 536 two large crickets meet  [ 159 3348] [0.0453379 0.9546621]
# Round 537 two large crickets meet  [ 159 3354] [0.04526046 0.95473954]
# Round 538 two large crickets meet  [ 159 3360] [0.04518329 0.95481671]
# Round 539 two large crickets meet  [ 159 3366] [0.04510638 0.95489362]
# Round 540 two large crickets meet  [ 159 3372] [0.04502974 0.95497026]
# Round 541 two large crickets meet  [ 159 3378] [0.04495335 0.95504665]
# Round 542 two large crickets meet  [ 159 3384] [0.04487722 0.95512278]
# Round 543 two large crickets meet  [ 159 3390] [0.04480135 0.95519865]
# Round 544 two large crickets meet  [ 159 3396] [0.04472574 0.95527426]
# Round 545 two large crickets meet  [ 159 3402] [0.04465038 0.95534962]
# Round 546 two large crickets meet  [ 159 3408] [0.04457527 0.95542473]
# Round 547 two large crickets meet  [ 159 3414] [0.04450042 0.95549958]
# Round 548 two large crickets meet  [ 159 3420] [0.04442582 0.95557418]
# Round 549 two large crickets meet  [ 159 3426] [0.04435146 0.95564854]
# Round 550 a small meets a large    [ 160 3434] [0.04451864 0.95548136]
# Round 551 two large crickets meet  [ 160 3440] [0.04444444 0.95555556]
# Round 552 two large crickets meet  [ 160 3446] [0.04437049 0.95562951]
# Round 553 two large crickets meet  [ 160 3452] [0.04429679 0.95570321]
# Round 554 two large crickets meet  [ 160 3458] [0.04422333 0.95577667]
# Round 555 two large crickets meet  [ 160 3464] [0.04415011 0.95584989]
# Round 556 two large crickets meet  [ 160 3470] [0.04407713 0.95592287]
# Round 557 two large crickets meet  [ 160 3476] [0.0440044 0.9559956]
# Round 558 two large crickets meet  [ 160 3482] [0.04393191 0.95606809]
# Round 559 two large crickets meet  [ 160 3488] [0.04385965 0.95614035]
# Round 560 two large crickets meet  [ 160 3494] [0.04378763 0.95621237]
# Round 561 two large crickets meet  [ 160 3500] [0.04371585 0.95628415]
# Round 562 a small meets a large    [ 161 3508] [0.04388117 0.95611883]
# Round 563 two large crickets meet  [ 161 3514] [0.04380952 0.95619048]
# Round 564 a small meets a large    [ 162 3522] [0.04397394 0.95602606]
# Round 565 two large crickets meet  [ 162 3528] [0.04390244 0.95609756]
# Round 566 two large crickets meet  [ 162 3534] [0.04383117 0.95616883]
# Round 567 two large crickets meet  [ 162 3540] [0.04376013 0.95623987]
# Round 568 two large crickets meet  [ 162 3546] [0.04368932 0.95631068]
# Round 569 two large crickets meet  [ 162 3552] [0.04361874 0.95638126]
# Round 570 two large crickets meet  [ 162 3558] [0.04354839 0.95645161]
# Round 571 two large crickets meet  [ 162 3564] [0.04347826 0.95652174]
# Round 572 two large crickets meet  [ 162 3570] [0.04340836 0.95659164]
# Round 573 two large crickets meet  [ 162 3576] [0.04333868 0.95666132]
# Round 574 two large crickets meet  [ 162 3582] [0.04326923 0.95673077]
# Round 575 two large crickets meet  [ 162 3588] [0.0432 0.9568]
# Round 576 two large crickets meet  [ 162 3594] [0.04313099 0.95686901]
# Round 577 two large crickets meet  [ 162 3600] [0.0430622 0.9569378]
# Round 578 two large crickets meet  [ 162 3606] [0.04299363 0.95700637]
# Round 579 two large crickets meet  [ 162 3612] [0.04292528 0.95707472]
# Round 580 two large crickets meet  [ 162 3618] [0.04285714 0.95714286]
# Round 581 two large crickets meet  [ 162 3624] [0.04278922 0.95721078]
# Round 582 two large crickets meet  [ 162 3630] [0.04272152 0.95727848]
# Round 583 two large crickets meet  [ 162 3636] [0.04265403 0.95734597]
# Round 584 two large crickets meet  [ 162 3642] [0.04258675 0.95741325]
# Round 585 two large crickets meet  [ 162 3648] [0.04251969 0.95748031]
# Round 586 two large crickets meet  [ 162 3654] [0.04245283 0.95754717]
# Round 587 two large crickets meet  [ 162 3660] [0.04238619 0.95761381]
# Round 588 two large crickets meet  [ 162 3666] [0.04231975 0.95768025]
# Round 589 a small meets a large    [ 163 3674] [0.04248111 0.95751889]
# Round 590 two large crickets meet  [ 163 3680] [0.04241478 0.95758522]
# Round 591 two large crickets meet  [ 163 3686] [0.04234866 0.95765134]
# Round 592 two large crickets meet  [ 163 3692] [0.04228275 0.95771725]
# Round 593 a small meets a large    [ 164 3700] [0.04244306 0.95755694]
# Round 594 two large crickets meet  [ 164 3706] [0.04237726 0.95762274]
# Round 595 two large crickets meet  [ 164 3712] [0.04231166 0.95768834]
# Round 596 two large crickets meet  [ 164 3718] [0.04224626 0.95775374]
# Round 597 two large crickets meet  [ 164 3724] [0.04218107 0.95781893]
# Round 598 a small meets a large    [ 165 3732] [0.04234026 0.95765974]
# Round 599 two large crickets meet  [ 165 3738] [0.04227517 0.95772483]
# Round 600 two large crickets meet  [ 165 3744] [0.04221028 0.95778972]
# Round 601 two large crickets meet  [ 165 3750] [0.04214559 0.95785441]
# Round 602 two large crickets meet  [ 165 3756] [0.0420811 0.9579189]
# Round 603 two large crickets meet  [ 165 3762] [0.04201681 0.95798319]
# Round 604 two large crickets meet  [ 165 3768] [0.04195271 0.95804729]
# Round 605 two large crickets meet  [ 165 3774] [0.0418888 0.9581112]
# Round 606 two large crickets meet  [ 165 3780] [0.0418251 0.9581749]
# Round 607 two large crickets meet  [ 165 3786] [0.04176158 0.95823842]
# Round 608 two large crickets meet  [ 165 3792] [0.04169826 0.95830174]
# Round 609 two large crickets meet  [ 165 3798] [0.04163512 0.95836488]
# Round 610 two large crickets meet  [ 165 3804] [0.04157218 0.95842782]
# Round 611 two large crickets meet  [ 165 3810] [0.04150943 0.95849057]
# Round 612 two large crickets meet  [ 165 3816] [0.04144687 0.95855313]
# Round 613 a small meets a large    [ 166 3824] [0.04160401 0.95839599]
# Round 614 a small meets a large    [ 167 3832] [0.04176044 0.95823956]
# Round 615 two large crickets meet  [ 167 3838] [0.04169788 0.95830212]
# Round 616 two large crickets meet  [ 167 3844] [0.0416355 0.9583645]
# Round 617 two large crickets meet  [ 167 3850] [0.04157331 0.95842669]
# Round 618 two large crickets meet  [ 167 3856] [0.04151131 0.95848869]
# Round 619 two large crickets meet  [ 167 3862] [0.04144949 0.95855051]
# Round 620 two large crickets meet  [ 167 3868] [0.04138786 0.95861214]
# Round 621 two large crickets meet  [ 167 3874] [0.0413264 0.9586736]
# Round 622 two large crickets meet  [ 167 3880] [0.04126513 0.95873487]
# Round 623 two large crickets meet  [ 167 3886] [0.04120405 0.95879595]
# Round 624 two large crickets meet  [ 167 3892] [0.04114314 0.95885686]
# Round 625 two large crickets meet  [ 167 3898] [0.04108241 0.95891759]
# Round 626 two large crickets meet  [ 167 3904] [0.04102186 0.95897814]
# Round 627 two large crickets meet  [ 167 3910] [0.04096149 0.95903851]
# Round 628 two large crickets meet  [ 167 3916] [0.0409013 0.9590987]
# Round 629 two large crickets meet  [ 167 3922] [0.04084128 0.95915872]
# Round 630 two large crickets meet  [ 167 3928] [0.04078144 0.95921856]
# Round 631 two large crickets meet  [ 167 3934] [0.04072178 0.95927822]
# Round 632 a small meets a large    [ 168 3942] [0.04087591 0.95912409]
# Round 633 two large crickets meet  [ 168 3948] [0.04081633 0.95918367]
# Round 634 two large crickets meet  [ 168 3954] [0.04075691 0.95924309]
# Round 635 two large crickets meet  [ 168 3960] [0.04069767 0.95930233]
# Round 636 a small meets a large    [ 169 3968] [0.04085086 0.95914914]
# Round 637 a small meets a large    [ 170 3976] [0.04100338 0.95899662]
# Round 638 two large crickets meet  [ 170 3982] [0.04094412 0.95905588]
# Round 639 a small meets a large    [ 171 3990] [0.04109589 0.95890411]
# Round 640 two large crickets meet  [ 171 3996] [0.04103672 0.95896328]
# Round 641 two large crickets meet  [ 171 4002] [0.04097771 0.95902229]
# Round 642 two large crickets meet  [ 171 4008] [0.04091888 0.95908112]
# Round 643 two large crickets meet  [ 171 4014] [0.04086022 0.95913978]
# Round 644 two large crickets meet  [ 171 4020] [0.04080172 0.95919828]
# Round 645 a small meets a large    [ 172 4028] [0.04095238 0.95904762]
# Round 646 two large crickets meet  [ 172 4034] [0.04089396 0.95910604]
# Round 647 two large crickets meet  [ 172 4040] [0.04083571 0.95916429]
# Round 648 two large crickets meet  [ 172 4046] [0.04077762 0.95922238]
# Round 649 two large crickets meet  [ 172 4052] [0.0407197 0.9592803]
# Round 650 a small meets a large    [ 173 4060] [0.04086936 0.95913064]
# Round 651 two large crickets meet  [ 173 4066] [0.04081151 0.95918849]
# Round 652 two large crickets meet  [ 173 4072] [0.04075383 0.95924617]
# Round 653 two large crickets meet  [ 173 4078] [0.04069631 0.95930369]
# Round 654 two large crickets meet  [ 173 4084] [0.04063895 0.95936105]
# Round 655 two large crickets meet  [ 173 4090] [0.04058175 0.95941825]
# Round 656 two large crickets meet  [ 173 4096] [0.04052471 0.95947529]
# Round 657 two large crickets meet  [ 173 4102] [0.04046784 0.95953216]
# Round 658 two large crickets meet  [ 173 4108] [0.04041112 0.95958888]
# Round 659 two large crickets meet  [ 173 4114] [0.04035456 0.95964544]
# Round 660 two large crickets meet  [ 173 4120] [0.04029816 0.95970184]
# Round 661 two large crickets meet  [ 173 4126] [0.04024192 0.95975808]
# Round 662 a small meets a large    [ 174 4134] [0.04038997 0.95961003]
# Round 663 a small meets a large    [ 175 4142] [0.04053741 0.95946259]
# Round 664 two large crickets meet  [ 175 4148] [0.04048115 0.95951885]
# Round 665 two large crickets meet  [ 175 4154] [0.04042504 0.95957496]
# Round 666 two large crickets meet  [ 175 4160] [0.04036909 0.95963091]
# Round 667 two large crickets meet  [ 175 4166] [0.04031329 0.95968671]
# Round 668 two large crickets meet  [ 175 4172] [0.04025765 0.95974235]
# Round 669 two large crickets meet  [ 175 4178] [0.04020216 0.95979784]
# Round 670 two large crickets meet  [ 175 4184] [0.04014682 0.95985318]
# Round 671 two large crickets meet  [ 175 4190] [0.04009164 0.95990836]
# Round 672 two large crickets meet  [ 175 4196] [0.0400366 0.9599634]
# Round 673 two large crickets meet  [ 175 4202] [0.03998172 0.96001828]
# Round 674 a small meets a large    [ 176 4210] [0.04012768 0.95987232]
# Round 675 two large crickets meet  [ 176 4216] [0.04007286 0.95992714]
# Round 676 a small meets a large    [ 177 4224] [0.04021813 0.95978187]
# Round 677 two large crickets meet  [ 177 4230] [0.04016338 0.95983662]
# Round 678 two large crickets meet  [ 177 4236] [0.04010877 0.95989123]
# Round 679 two large crickets meet  [ 177 4242] [0.04005431 0.95994569]
# Round 680 a small meets a large    [ 178 4250] [0.04019874 0.95980126]
# Round 681 two large crickets meet  [ 178 4256] [0.04014434 0.95985566]
# Round 682 two large crickets meet  [ 178 4262] [0.04009009 0.95990991]
# Round 683 two large crickets meet  [ 178 4268] [0.04003599 0.95996401]
# ...
# Round 775 two large crickets meet  [ 182 4828] [0.03632735 0.96367265]
# Round 776 two large crickets meet  [ 182 4834] [0.03628389 0.96371611]
# Round 777 two large crickets meet  [ 182 4840] [0.03624054 0.96375946]
# Round 778 two large crickets meet  [ 182 4846] [0.0361973 0.9638027]
# Round 779 a small meets a large    [ 183 4854] [0.03633115 0.96366885]
# Round 780 a small meets a large    [ 184 4862] [0.03646453 0.96353547]
# Round 781 two large crickets meet  [ 184 4868] [0.03642122 0.96357878]
# Round 782 two large crickets meet  [ 184 4874] [0.03637802 0.96362198]
# Round 783 two large crickets meet  [ 184 4880] [0.03633491 0.96366509]
# Round 784 two large crickets meet  [ 184 4886] [0.03629191 0.96370809]
# Round 785 two large crickets meet  [ 184 4892] [0.03624901 0.96375099]
# Round 786 two large crickets meet  [ 184 4898] [0.03620622 0.96379378]
# Round 787 two large crickets meet  [ 184 4904] [0.03616352 0.96383648]
# Round 788 two large crickets meet  [ 184 4910] [0.03612093 0.96387907]
# Round 789 a small meets a large    [ 185 4918] [0.03625318 0.96374682]
# Round 790 two large crickets meet  [ 185 4924] [0.03621061 0.96378939]
# Round 791 two large crickets meet  [ 185 4930] [0.03616813 0.96383187]
# Round 792 two large crickets meet  [ 185 4936] [0.03612576 0.96387424]
# Round 793 two large crickets meet  [ 185 4942] [0.03608348 0.96391652]
# Round 794 two large crickets meet  [ 185 4948] [0.0360413 0.9639587]
# Round 795 two large crickets meet  [ 185 4954] [0.03599922 0.96400078]
# Round 796 a small meets a large    [ 186 4962] [0.03613054 0.96386946]
# Round 797 two large crickets meet  [ 186 4968] [0.03608847 0.96391153]
# Round 798 two large crickets meet  [ 186 4974] [0.03604651 0.96395349]
# Round 799 two large crickets meet  [ 186 4980] [0.03600465 0.96399535]
# Round 800 two large crickets meet  [ 186 4986] [0.03596288 0.96403712]
# Round 801 a small meets a large    [ 187 4994] [0.03609342 0.96390658]
# Round 802 two large crickets meet  [ 187 5000] [0.03605167 0.96394833]
# Round 803 two large crickets meet  [ 187 5006] [0.03601001 0.96398999]
# Round 804 two large crickets meet  [ 187 5012] [0.03596846 0.96403154]
# Round 805 two large crickets meet  [ 187 5018] [0.03592699 0.96407301]
# Round 806 two large crickets meet  [ 187 5024] [0.03588563 0.96411437]
# Round 807 two large crickets meet  [ 187 5030] [0.03584435 0.96415565]
# Round 808 two large crickets meet  [ 187 5036] [0.03580318 0.96419682]
# Round 809 two large crickets meet  [ 187 5042] [0.0357621 0.9642379]
# Round 810 two large crickets meet  [ 187 5048] [0.03572111 0.96427889]
# Round 811 two large crickets meet  [ 187 5054] [0.03568021 0.96431979]
# Round 812 two large crickets meet  [ 187 5060] [0.03563941 0.96436059]
# Round 813 two large crickets meet  [ 187 5066] [0.03559871 0.96440129]
# Round 814 two large crickets meet  [ 187 5072] [0.03555809 0.96444191]
# Round 815 two large crickets meet  [ 187 5078] [0.03551757 0.96448243]
# Round 816 two large crickets meet  [ 187 5084] [0.03547714 0.96452286]
# Round 817 two large crickets meet  [ 187 5090] [0.0354368 0.9645632]
# Round 818 two large crickets meet  [ 187 5096] [0.03539655 0.96460345]
# Round 819 two large crickets meet  [ 187 5102] [0.0353564 0.9646436]
# Round 820 two large crickets meet  [ 187 5108] [0.03531634 0.96468366]
# Round 821 two large crickets meet  [ 187 5114] [0.03527636 0.96472364]
# Round 822 two large crickets meet  [ 187 5120] [0.03523648 0.96476352]
# Round 823 two large crickets meet  [ 187 5126] [0.03519669 0.96480331]
# Round 824 two large crickets meet  [ 187 5132] [0.03515698 0.96484302]
# Round 825 two large crickets meet  [ 187 5138] [0.03511737 0.96488263]
# Round 826 two large crickets meet  [ 187 5144] [0.03507785 0.96492215]
# Round 827 two large crickets meet  [ 187 5150] [0.03503841 0.96496159]
# Round 828 two large crickets meet  [ 187 5156] [0.03499906 0.96500094]
# Round 829 two large crickets meet  [ 187 5162] [0.03495981 0.96504019]
# Round 830 two large crickets meet  [ 187 5168] [0.03492063 0.96507937]
# Round 831 two large crickets meet  [ 187 5174] [0.03488155 0.96511845]
# Round 832 two large crickets meet  [ 187 5180] [0.03484256 0.96515744]
# Round 833 two large crickets meet  [ 187 5186] [0.03480365 0.96519635]
# Round 834 two large crickets meet  [ 187 5192] [0.03476483 0.96523517]
# Round 835 two large crickets meet  [ 187 5198] [0.03472609 0.96527391]
# Round 836 two large crickets meet  [ 187 5204] [0.03468744 0.96531256]
# Round 837 two large crickets meet  [ 187 5210] [0.03464888 0.96535112]
# Round 838 two large crickets meet  [ 187 5216] [0.0346104 0.9653896]
# Round 839 a small meets a large    [ 188 5224] [0.03473762 0.96526238]
# Round 840 two large crickets meet  [ 188 5230] [0.03469915 0.96530085]
# Round 841 two large crickets meet  [ 188 5236] [0.03466077 0.96533923]
# Round 842 two large crickets meet  [ 188 5242] [0.03462247 0.96537753]
# Round 843 two large crickets meet  [ 188 5248] [0.03458425 0.96541575]
# Round 844 two large crickets meet  [ 188 5254] [0.03454612 0.96545388]
# Round 845 two large crickets meet  [ 188 5260] [0.03450808 0.96549192]
# Round 846 two large crickets meet  [ 188 5266] [0.03447011 0.96552989]
# Round 847 two large crickets meet  [ 188 5272] [0.03443223 0.96556777]
# Round 848 two large crickets meet  [ 188 5278] [0.03439444 0.96560556]
# Round 849 two large crickets meet  [ 188 5284] [0.03435673 0.96564327]
# Round 850 two large crickets meet  [ 188 5290] [0.03431909 0.96568091]
# Round 851 two large crickets meet  [ 188 5296] [0.03428155 0.96571845]
# Round 852 two large crickets meet  [ 188 5302] [0.03424408 0.96575592]
# Round 853 two large crickets meet  [ 188 5308] [0.0342067 0.9657933]
# Round 854 two large crickets meet  [ 188 5314] [0.03416939 0.96583061]
# Round 855 two large crickets meet  [ 188 5320] [0.03413217 0.96586783]
# Round 856 two large crickets meet  [ 188 5326] [0.03409503 0.96590497]
# Round 857 two large crickets meet  [ 188 5332] [0.03405797 0.96594203]
# Round 858 two large crickets meet  [ 188 5338] [0.03402099 0.96597901]
# Round 859 two large crickets meet  [ 188 5344] [0.03398409 0.96601591]
# Round 860 two large crickets meet  [ 188 5350] [0.03394727 0.96605273]
# Round 861 two large crickets meet  [ 188 5356] [0.03391053 0.96608947]
# Round 862 two large crickets meet  [ 188 5362] [0.03387387 0.96612613]
# Round 863 two large crickets meet  [ 188 5368] [0.03383729 0.96616271]
# Round 864 two large crickets meet  [ 188 5374] [0.03380079 0.96619921]
# Round 865 two large crickets meet  [ 188 5380] [0.03376437 0.96623563]
# Round 866 two large crickets meet  [ 188 5386] [0.03372802 0.96627198]
# Round 867 two large crickets meet  [ 188 5392] [0.03369176 0.96630824]
# Round 868 two large crickets meet  [ 188 5398] [0.03365557 0.96634443]
# Round 869 two large crickets meet  [ 188 5404] [0.03361946 0.96638054]
# Round 870 two large crickets meet  [ 188 5410] [0.03358342 0.96641658]
# Round 871 two large crickets meet  [ 188 5416] [0.03354747 0.96645253]
# Round 872 two large crickets meet  [ 188 5422] [0.03351159 0.96648841]
# Round 873 two large crickets meet  [ 188 5428] [0.03347578 0.96652422]
# Round 874 a small meets a large    [ 189 5436] [0.0336 0.9664]
# Round 875 two large crickets meet  [ 189 5442] [0.0335642 0.9664358]
# Round 876 two large crickets meet  [ 189 5448] [0.03352847 0.96647153]
# Round 877 two large crickets meet  [ 189 5454] [0.03349282 0.96650718]
# Round 878 two large crickets meet  [ 189 5460] [0.03345725 0.96654275]
# Round 879 two large crickets meet  [ 189 5466] [0.03342175 0.96657825]
# Round 880 two large crickets meet  [ 189 5472] [0.03338633 0.96661367]
# Round 881 two large crickets meet  [ 189 5478] [0.03335098 0.96664902]
# Round 882 two large crickets meet  [ 189 5484] [0.03331571 0.96668429]
# Round 883 two large crickets meet  [ 189 5490] [0.03328051 0.96671949]
# Round 884 two large crickets meet  [ 189 5496] [0.03324538 0.96675462]
# Round 885 two large crickets meet  [ 189 5502] [0.03321033 0.96678967]
# Round 886 two large crickets meet  [ 189 5508] [0.03317536 0.96682464]
# Round 887 two large crickets meet  [ 189 5514] [0.03314045 0.96685955]
# Round 888 two large crickets meet  [ 189 5520] [0.03310562 0.96689438]
# Round 889 two large crickets meet  [ 189 5526] [0.03307087 0.96692913]
# Round 890 two large crickets meet  [ 189 5532] [0.03303618 0.96696382]
# Round 891 two large crickets meet  [ 189 5538] [0.03300157 0.96699843]
# Round 892 two large crickets meet  [ 189 5544] [0.03296703 0.96703297]
# Round 893 two large crickets meet  [ 189 5550] [0.03293257 0.96706743]
# Round 894 two large crickets meet  [ 189 5556] [0.03289817 0.96710183]
# Round 895 two large crickets meet  [ 189 5562] [0.03286385 0.96713615]
# Round 896 two large crickets meet  [ 189 5568] [0.0328296 0.9671704]
# Round 897 two large crickets meet  [ 189 5574] [0.03279542 0.96720458]
# Round 898 two large crickets meet  [ 189 5580] [0.03276131 0.96723869]
# Round 899 two large crickets meet  [ 189 5586] [0.03272727 0.96727273]
# Round 900 two large crickets meet  [ 189 5592] [0.03269331 0.96730669]
# Round 901 two large crickets meet  [ 189 5598] [0.03265941 0.96734059]
# Round 902 two large crickets meet  [ 189 5604] [0.03262558 0.96737442]
# Round 903 two large crickets meet  [ 189 5610] [0.03259183 0.96740817]
# Round 904 two large crickets meet  [ 189 5616] [0.03255814 0.96744186]
# Round 905 two large crickets meet  [ 189 5622] [0.03252452 0.96747548]
# Round 906 two large crickets meet  [ 189 5628] [0.03249097 0.96750903]
# Round 907 two large crickets meet  [ 189 5634] [0.0324575 0.9675425]
# Round 908 two large crickets meet  [ 189 5640] [0.03242409 0.96757591]
# Round 909 two large crickets meet  [ 189 5646] [0.03239075 0.96760925]
# Round 910 two large crickets meet  [ 189 5652] [0.03235747 0.96764253]
# Round 911 two large crickets meet  [ 189 5658] [0.03232427 0.96767573]
# Round 912 two large crickets meet  [ 189 5664] [0.03229113 0.96770887]
# Round 913 two large crickets meet  [ 189 5670] [0.03225806 0.96774194]
# Round 914 a small meets a large    [ 190 5678] [0.032379 0.967621]
# Round 915 two large crickets meet  [ 190 5684] [0.03234593 0.96765407]
# Round 916 a small meets a large    [ 191 5692] [0.03246643 0.96753357]
# Round 917 two large crickets meet  [ 191 5698] [0.03243335 0.96756665]
# Round 918 two large crickets meet  [ 191 5704] [0.03240034 0.96759966]
# Round 919 two large crickets meet  [ 191 5710] [0.0323674 0.9676326]
# Round 920 two large crickets meet  [ 191 5716] [0.03233452 0.96766548]
# Round 921 a small meets a large    [ 192 5724] [0.03245436 0.96754564]
# Round 922 two large crickets meet  [ 192 5730] [0.03242148 0.96757852]
# Round 923 two large crickets meet  [ 192 5736] [0.03238866 0.96761134]
# Round 924 two large crickets meet  [ 192 5742] [0.03235592 0.96764408]
# Round 925 two large crickets meet  [ 192 5748] [0.03232323 0.96767677]
# Round 926 two large crickets meet  [ 192 5754] [0.03229062 0.96770938]
# Round 927 two large crickets meet  [ 192 5760] [0.03225806 0.96774194]
# Round 928 two large crickets meet  [ 192 5766] [0.03222558 0.96777442]
# Round 929 two large crickets meet  [ 192 5772] [0.03219316 0.96780684]
# Round 930 two large crickets meet  [ 192 5778] [0.0321608 0.9678392]
# Round 931 two large crickets meet  [ 192 5784] [0.03212851 0.96787149]
# Round 932 two large crickets meet  [ 192 5790] [0.03209629 0.96790371]
# Round 933 two large crickets meet  [ 192 5796] [0.03206413 0.96793587]
# Round 934 two large crickets meet  [ 192 5802] [0.03203203 0.96796797]
# Round 935 two large crickets meet  [ 192 5808] [0.032 0.968]
# Round 936 two large crickets meet  [ 192 5814] [0.03196803 0.96803197]
# Round 937 two large crickets meet  [ 192 5820] [0.03193613 0.96806387]
# Round 938 a small meets a large    [ 193 5828] [0.03205448 0.96794552]
# Round 939 two large crickets meet  [ 193 5834] [0.03202257 0.96797743]
# Round 940 two large crickets meet  [ 193 5840] [0.03199072 0.96800928]
# Round 941 two large crickets meet  [ 193 5846] [0.03195893 0.96804107]
# Round 942 two large crickets meet  [ 193 5852] [0.03192721 0.96807279]
# Round 943 two large crickets meet  [ 193 5858] [0.03189555 0.96810445]
# Round 944 two large crickets meet  [ 193 5864] [0.03186396 0.96813604]
# Round 945 a small meets a large    [ 194 5872] [0.03198154 0.96801846]
# Round 946 two large crickets meet  [ 194 5878] [0.03194993 0.96805007]
# Round 947 two large crickets meet  [ 194 5884] [0.03191839 0.96808161]
# Round 948 two large crickets meet  [ 194 5890] [0.03188692 0.96811308]
# Round 949 two large crickets meet  [ 194 5896] [0.0318555 0.9681445]
# Round 950 two large crickets meet  [ 194 5902] [0.03182415 0.96817585]
# Round 951 two large crickets meet  [ 194 5908] [0.03179285 0.96820715]
# Round 952 two large crickets meet  [ 194 5914] [0.03176162 0.96823838]
# Round 953 two large crickets meet  [ 194 5920] [0.03173045 0.96826955]
# Round 954 two large crickets meet  [ 194 5926] [0.03169935 0.96830065]
# Round 955 two large crickets meet  [ 194 5932] [0.0316683 0.9683317]
# Round 956 two large crickets meet  [ 194 5938] [0.03163731 0.96836269]
# Round 957 two large crickets meet  [ 194 5944] [0.03160639 0.96839361]
# Round 958 two large crickets meet  [ 194 5950] [0.03157552 0.96842448]
# Round 959 two large crickets meet  [ 194 5956] [0.03154472 0.96845528]
# Round 960 two large crickets meet  [ 194 5962] [0.03151397 0.96848603]
# Round 961 two large crickets meet  [ 194 5968] [0.03148328 0.96851672]
# Round 962 two large crickets meet  [ 194 5974] [0.03145266 0.96854734]
# Round 963 two large crickets meet  [ 194 5980] [0.03142209 0.96857791]
# Round 964 two large crickets meet  [ 194 5986] [0.03139159 0.96860841]
# Round 965 two large crickets meet  [ 194 5992] [0.03136114 0.96863886]
# Round 966 two large crickets meet  [ 194 5998] [0.03133075 0.96866925]
# Round 967 a small meets a large    [ 195 6006] [0.03144654 0.96855346]
# Round 968 two large crickets meet  [ 195 6012] [0.03141614 0.96858386]
# Round 969 two large crickets meet  [ 195 6018] [0.0313858 0.9686142]
# Round 970 two large crickets meet  [ 195 6024] [0.03135552 0.96864448]
# Round 971 two large crickets meet  [ 195 6030] [0.0313253 0.9686747]
# Round 972 two large crickets meet  [ 195 6036] [0.03129514 0.96870486]
# Round 973 two large crickets meet  [ 195 6042] [0.03126503 0.96873497]
# Round 974 two large crickets meet  [ 195 6048] [0.03123498 0.96876502]
# Round 975 two large crickets meet  [ 195 6054] [0.03120499 0.96879501]
# Round 976 two large crickets meet  [ 195 6060] [0.03117506 0.96882494]
# Round 977 two large crickets meet  [ 195 6066] [0.03114518 0.96885482]
# Round 978 two large crickets meet  [ 195 6072] [0.03111537 0.96888463]
# Round 979 two large crickets meet  [ 195 6078] [0.0310856 0.9689144]
# Round 980 two large crickets meet  [ 195 6084] [0.0310559 0.9689441]
# Round 981 two large crickets meet  [ 195 6090] [0.03102625 0.96897375]
# Round 982 two large crickets meet  [ 195 6096] [0.03099666 0.96900334]
# Round 983 two large crickets meet  [ 195 6102] [0.03096713 0.96903287]
# Round 984 two large crickets meet  [ 195 6108] [0.03093765 0.96906235]
# Round 985 two large crickets meet  [ 195 6114] [0.03090823 0.96909177]
# Round 986 two large crickets meet  [ 195 6120] [0.03087886 0.96912114]
# Round 987 two large crickets meet  [ 195 6126] [0.03084955 0.96915045]
# Round 988 two large crickets meet  [ 195 6132] [0.03082029 0.96917971]
# Round 989 a small meets a large    [ 196 6140] [0.03093434 0.96906566]
# Round 990 two large crickets meet  [ 196 6146] [0.03090508 0.96909492]
# Round 991 two large crickets meet  [ 196 6152] [0.03087587 0.96912413]
# Round 992 two large crickets meet  [ 196 6158] [0.03084671 0.96915329]
# Round 993 two large crickets meet  [ 196 6164] [0.03081761 0.96918239]
# Round 994 a small meets a large    [ 197 6172] [0.03093107 0.96906893]
# Round 995 two large crickets meet  [ 197 6178] [0.03090196 0.96909804]
# Round 996 two large crickets meet  [ 197 6184] [0.0308729 0.9691271]
# Round 997 two large crickets meet  [ 197 6190] [0.0308439 0.9691561]
# Round 998 two large crickets meet  [ 197 6196] [0.03081495 0.96918505]
# Round 999 two large crickets meet  [ 197 6202] [0.03078606 0.96921394]
# Round 1000 two large crickets meet  [ 197 6208] [0.03075722 0.96924278]

# %% [markdown]
# The above simulation displays, after each encounter, the number of individuals of each type and the fraction of individuals of each type.   Run the simulation multiple times for different initial conditions.
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 2:</SPAN>**  Answer the following questions.   You do not need to provide code for this problem, but explain your answers.
# <ol>
# <li> How quickly does the total population grow if initally all the crickets are small?
# <li> How quickly does the total population grow if initally all the crickets are large?
# <li> Do the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero? (To explore convergence you may need to increase the number of encounters simulated.)
# </ol>

# %% [markdown]
# __Answer:__ (Your answer here)
#
# problem 2.1
#
# Each round of the total population growing is 10 if initally all the crickets are small.
#
# problem 2.2
#
# Each round of the total population growing is 6 if initally all the crickets are large.
#
# problem 2.3
#
# Yes,it converges.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 2</SPAN>**

# %% [markdown]
# The code given next is essentially the same as above.  One difference is a time variable is added such that the average rate that an individual cricket has encounters is proportional to the total number of crickets.  This results in exponential growth of the population with time.    Another difference is that population sizes are saved and plotted.

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted

F=np.array([[5,1],[8,3]])  # fitness matrix
n_max=100  # maximum number of interactions
n=np.zeros((n_max,2),dtype=float)
time=np.zeros(n_max,dtype=float)

n[0,0], n[0,1] = 4,4 # initial [number of small crickets, number of large crickets]

for k in range(n_max-1):
    time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
    a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
    b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n[k+1,:]= n[k,:] + [2*F[0,0],0]
    elif a<U<=a+b:
        n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
    else:
        n[k+1,:]= n[k,:] + [0,2*F[1,1]]

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.text(1.1,n[80,0], r'small',fontsize=14)
plt.text(1.1,n[80,1], r'large',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (simulation)")

# %% [markdown]
# The following code computes the deterministic analog of the cricket evolution.  The basic idea is that if the current population is [n[0], n[1]] then the drift (i.e. the expected rate of increase) of n[0] is n[0]  multiplied by the expected number of small crickets generated by a small cricket if an encounter happens.  That is true because each of the existing small crikets is having encounters at expected rate one.   To calculate the mean number of new small crickets generated by the encounter of a small cricket with a randomly selected other cricket, we use the law of total probability.  The encountered cricket is type zero with probabiity n[0]/(n[0]+n[1]), which results in F[0,0] new crickets of type zero, and the encountered cricket is type one with probability n[1]/(n[0]+n[1]), which results in F[0,1] new crickets of type zero.   Combining we get
# $$
# \dot{n}[0] = n[0]*(F[0,0]*n[0]+F[0,1]*n[1])/(n[0]+n[1])
# $$
# The equation just derived is based on the law of large numbers (LLN).  If the population is fairly large then no one individual plays a major role in the evolution.  Over a small period of time the ratios of small and large crickets is nearly constant, so the number of new crickets of each type in each time slot are nearly independent and identically distributed.   The LLN suggests approximating the sum of number of individuals of each type by the expected numbers of individuals of each type.  That's how we arrive at a deterministic differential equation.
#
# A similar expression holds for the derivative of n[1], and the two equations can be writen in matrix form as
# $$
# \dot{n} = diag(n)*F*n/sum(n)
# $$
# where diag(n) is the diagonal matrix with n[0] and n[1] on the diagonal, and "$*$" represents usual matrix multiplication.   (In the python code below, "$*$" denotes element by element multiplication, which is used instead of creating a diagonal matrix, and np.dot is used for ordinary matrix multiplication.)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")

# %% [markdown]
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 3:</SPAN>** Run the code above and compare the output to the output of the previous code for stochastic evolutionary dynamics.  Try different intial conditions such as [0,4], [4,0], and [10,1]. Comment on how the result of this compares to our previous simulation. Is the behavior similar?

# %% [markdown]
# __Answer__: (Your answer here)
#
# Yes, the behavior is similar.They both have exponential shape while the increasing rate shows a little difference.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 3</SPAN>**

# %% [markdown]
# If we let $\theta[0]=\frac{n[0]}{n[0]+n[1]}$ and $\theta[1]=\frac{n[1]}{n[0]+n[1]}$ then the vector $\theta=\binom{\theta[0]}{\theta[1]}$ describes the fractions of the popuation of each type.  It's entries sum to one.  Using the chain rule of calculus we can derive the following differential equation for $\theta$ from the above ode for $n$:
# $$
# \dot{\theta} = diag(\theta) \left( F\theta - \mathbf{1} \theta^T F \theta \right)
# $$
# where $\mathbf{1}$ is the column vector of ones (the derivation is a bit involved, try deriving it by yourself if interested, but it is not required). The two components of the vector $F \theta$ give the average fitness level of small crickets and large crickets, respectively, in an encounter with a cricket selected randomly from the population.   And $\theta^T F \theta$ is the weighted average of that vector, giving the average fitness over all crickets in the population.   Thus, $\theta[0]$ is increasing exactly when the fitness of small crickets is greater than the average fitness.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 4:</SPAN>**
#
# 1. Modify the above code to integrate the equation for the $\theta$ vector to obtain $\theta$ vs. time.
# To check your answer, compare it to what you get by first computing the trajectory of $n$ and then calculating $\theta$ from $n.$  (The code given above for deterministic evolution of n works for any number of types, not just two types. A problem below involves three types of individuals, so it'd be nice if you could implement your code for computing $\theta$ to work for any number of types.) __Be careful when you write your program, since matrix multiplication in Python can be tricky. Understand "$*$" multiplication and np.dot multiplication first. After each small step, debug, confirm, then proceed.__
# 2. Using the fact that $\theta[1]=1-\theta[0],$  a differential equation can be derived for the variable $\theta[0]$ alone.
# Plot the function $h$ on the interval $[0,1]$ such that $\dot{\theta}[0]=h(\theta[0]).$ Note that the horizontal axis of the graph is $\theta$, the vertical axis is $\dot{\theta}$. (You can just do this
# numerically.  It can also be done algebrically; in fact $h$ is a cubic polynomial, but it is a bit complicated to find the polynomial.)
# 3. What are the zeroes of $h$ (those are the equilibrium points of $\theta[0]$)?  Which of those are stable (in the sense that if $\theta[0]$ is slightly moved away from the equilibrium point, it returns to the equilibrium point)?

# %%
# Your code here
print("------------------------------------------Problem 4.1-----------------------------------------------------")
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)
ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)
theta=n/(np.array([n.sum(axis=1),n.sum(axis=1)]).transpose())
plt.plot(time,theta[:,0],'orange')
plt.plot(time,theta[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,theta[800,0], r'small',fontsize=14)
plt.text(1.1,theta[800,1], r'large',fontsize=14)
plt.ylabel('P size')
plt.title("P of small and large crickets vs. time (ode prediction)")
plt.figure()

def fNew(theta,t):
    l=len(theta)
    one=np.ones(l)
    F_theta=np.dot(F,theta)
    the_F_theta=np.dot(theta.transpose(),F_theta)
    one_theFtheta=np.dot(one,the_F_theta)
    return theta*(F_theta - one_theFtheta)

time=np.linspace(0.0,1.5, 1000)
theinit=[0.5,0.5]

the=odeint(fNew,theinit,time)
plt.plot(time,the[:,0],'orange')
plt.plot(time,the[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,the[800,0], r'small',fontsize=14)
plt.text(1.1,the[800,1], r'large',fontsize=14)
plt.ylabel('P size')
plt.title("P of small and large crickets vs. theta (ode prediction)")
# Out:
# ------------------------------------------Problem 4.1-----------------------------------------------------

# %%
print("------------------------------------------Problem 4.2-----------------------------------------------------")
def h(the0):
    theta=[the0,1-the0]
    length=len(theta)
    one=np.ones(length)
    
    Ftheta=np.dot(F,theta)
    theFtheta=np.dot(theta,Ftheta)
    onetheFtheta=np.dot(one,theFtheta)
    return (theta*(Ftheta - onetheFtheta))[0]

the0=np.linspace(0,1,1000)
plt.figure()
plt.plot(the0,list(map(h,the0)),'blue')
plt.xlabel('theta 0')
plt.ylabel('theta hat')
plt.title("theta 0 vs. theta hat")
# Out:
# ------------------------------------------Problem 4.2-----------------------------------------------------

# %% [markdown]
# __Answer:__ (Your answer here)
#
# #Problem 4.3
#
# Zeroes of h: when theta0 equals to 0.0 or 1.0
#
# stable point: Point 0

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 4</SPAN>**

# %% [markdown]
# The overall behavior in evolutionary games depends heavily on the fitness matrix $F.$   Another choice of $F$ corresponds to the so-called doves and hawks evolution game, for which the fitness matrix is
# $$\begin{array}{c|cc}  & dove & hawk  \\ \hline
#     dove & 3 & 1  \\
#     hawk & 5 & 0
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  3 & 1 \\ 5 & 0  \end{array}\right).$$   Think of the doves and hawks as two types of birds that need to share resources, such as food.  (The hawks are so aggressive that they attack the doves).  A dove has higher fitness, 3, against another dove than against a hawk, 1.  A hawk has a high fitness against a dove (5) but zero fitness against another hawk, because the hawks fight over their resources.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 5:</SPAN>**
#
# 1. Repeat the deterministic (ode) approach above, but now for the doves and hawks evolution game.   You can use either the random or deterministic evolution equations for the numerical analysis.
# 2. Comment and verify your assertions about equilibrium behavior by finding a differential equation for $\theta[0]$ and exploring its equilbrium points and their stability.

# %%
# Your code here
print("------------------------------------------Problem 5.1-----------------------------------------------------")
F=np.array([[3,1],[5,0]])
def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[5,5] 
time=np.linspace(0.0,1.5, 1000)
n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'dove',fontsize=14)
plt.text(1.1,n[800,1], r'hawk',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# ------------------------------------------Problem 5.1-----------------------------------------------------

# %%
print("------------------------------------------Problem 5.2-----------------------------------------------------")
def h(theta0):
    theta=[theta0,1-theta0]
    length=len(theta)
    one=np.ones(length)
    Ftheta=np.dot(F,theta)
    theFtheta=np.dot(theta,Ftheta)
    onetheFtheta=np.dot(one,theFtheta)
    return (theta*(Ftheta-onetheFtheta))[0]

theta0=np.linspace(0,1,1000)
plt.plot(the0,list(map(h,the0)),'orange')
dis=float('inf')
zero=0
for the in the0:
    if the!=0 and zero!=1 :
        if abs(h(the))<dis:
            dis=abs(h(the))
            zero=the
            
print("parts of zero of h:",zero)
# Out:
# ------------------------------------------Problem 5.2-----------------------------------------------------
# parts of zero of h: 0.3333333333333333

# %% [markdown]
# __Answer__: (Your answer here)
#
# Equilibrium points : 0, 0.33333333, 1
#
# Stable point: 0.33333333

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 5</SPAN>**

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 6:</SPAN>**  Find a 3x3 fitness matrix $F$ and an initial condition for an evolutionary game with three types of individuals such that the solution $\theta$ has a limit cycle, not just converging to a limit point.  Does the limit cycle depend on the intial state for your fitness matrix?
#
# Hint 1: Adapt the code you wrote for Problem 4.
#
# Hint 2: Solve this problem by trial and error, i.e. trying different values of the entries in the fitness matrix. Think of the three types of individuals as three kinds of animals. What kind of relationship among these three animals would likely to cause an oscillating population for each animal?

# %%
# Your code here
F=np.array([[5,0,5],[5,5,0],[0,8,0]])
def f6(theta,t):
    l=len(theta)
    one=np.ones(l)
    Ftheta=np.dot(F,theta)
    theFtheta=np.dot(theta.transpose(),Ftheta)
    onetheFtheta=np.dot(one,theFtheta)
    return theta*(Ftheta-onetheFtheta)

print("P with initialized as (0.4,0.4,0.2)")

time=np.linspace(0.0,20, 1000)
theinit=[0.4,0.4,0.2]
theta=odeint(f6,theinit,time)
plt.plot(time,theta[:,0],'green')
plt.plot(time,theta[:,1],'blue')
plt.plot(time,theta[:,2],'red')
plt.text(1.1,the[800,0], r'A',fontsize=14)
plt.text(1.1,the[800,1], r'B',fontsize=14)
plt.text(1.1,the[800,2], r'C',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# P with initialized as (0.4,0.4,0.2)

# %%
print("p is initialized as (0.6,0.4,0)")
time=np.linspace(0.0,20, 1000)
theinit=[0.6,0.4,0]
the=odeint(f6,theinit,time)
plt.figure()
plt.plot(time,the[:,0],'')
plt.plot(time,the[:,1],'blue')
plt.plot(time,the[:,2],'red')
plt.xlabel('time')
plt.text(1.1,the[800,0], r'A',fontsize=14)
plt.text(1.1,the[800,1], r'B',fontsize=14)
plt.text(1.1,the[800,2], r'C',fontsize=14)
plt.ylabel('P size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# p is initialized as (0.6,0.4,0)

# %% [markdown]
# __Answer__: (Your answer here)
#
# Yes, the limit cycle does depend on the initial state, because in second graph we can see that the cycle disappear as time increases, which means the ecological balance is destroyed.
#
# For causing an oscillating population for each animal, the relationship amoung them should be that A is the predator of C, C is the predator of B, and B is the predator of A, because when the number of A decreases, the number of C increases and when the number of B increases, the number of A decreases. They set up an ecological balance.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 6</SPAN>**

# %% [markdown]
# For this week's lab, please answer all questions 1-6.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ## Academic Integrity Statement ##
#
# By submitting the lab with this statement, you declare you have written up the lab entirely by yourself, including both code and markdown cells. You also agree that you should not share your code with anyone else. Any violation of the academic integrity requirement may cause an academic integrity report to be filed that could go into your student record. See <a href="https://provost.illinois.edu/policies/policies/academic-integrity/students-quick-reference-guide-to-academic-integrity/">Students' Quick Reference Guide to Academic Integrity</a> for more information.
